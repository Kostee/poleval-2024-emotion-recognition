# %% [markdown]
# # Load Libraries

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split, KFold
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
# Out:
# C:\Users\panko\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\scipy\__init__.py:177: UserWarning: A NumPy version >=1.18.5 and <1.26.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Change the directory

# %%
import os
os.chdir("../../../")
# from google.colab import drive
# drive.mount('/content/drive/')
# %cd drive/MyDrive/poleval_emotion/

# %% [markdown]
# # Determine constants

# %%
TRAIN_DIR = 'data/train/'
IN_FILENAME = 'in_prep_bas.tsv'
EXPECTED_FILENAME = 'expected.tsv'

# %% [markdown]
# # Load & preprocess data functions

# %%
def load_data(file_path):
    data = pd.read_csv(file_path, sep='\t')
    return data

# %%
def preprocess_data(text_series, num_words=5000):
    text_series = text_series.astype(str)
    tokenizer = Tokenizer(num_words=num_words)
    tokenizer.fit_on_texts(text_series)
    sequences = tokenizer.texts_to_sequences(text_series)
    max_len = max(len(x) for x in sequences)
    padded_sequences = pad_sequences(sequences, maxlen=max_len)
    return padded_sequences, tokenizer

# %% [markdown]
# # Define the LSTM model

# %%
def create_model():
    model = Sequential([
        Embedding(input_dim=5000, output_dim=128),
        LSTM(64),
        Dense(11, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %% [markdown]
# # Load & preprocess the data

# %%
in_data = load_data(TRAIN_DIR + IN_FILENAME)
expected_data = load_data(TRAIN_DIR + EXPECTED_FILENAME)

# %%
X, tokenizer = preprocess_data(in_data['text'])
y = expected_data.values

# %% [markdown]
# # Cross-validation setup

# %%
num_splits = 5
num_repeats = 5
kf = KFold(n_splits=num_splits, shuffle=True, random_state=1613)

# %% [markdown]
# # Main operation

# %%
overall_accuracies = []
all_labels_accuracies = []

# %%
for repeat in range(num_repeats):
    fold_accuracies = []
    fold_labels_accuracies = []
    fold_no = 1
    for train_index, test_index in kf.split(X):
        print(f"Repeat {repeat+1}, Fold {fold_no} started.")
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]

        model = create_model()
        history = model.fit(X_train, y_train, batch_size=32, epochs=16, validation_data=(X_test, y_test), verbose=0)

        # Model evaluation
        scores = model.evaluate(X_test, y_test, verbose=0)
        fold_accuracies.append(scores[1])
        print(f'Score for repeat {repeat+1}, fold {fold_no}: {model.metrics_names[1]} of {scores[1]:.4f}')

        # Calculating the accuracy for each label
        predictions = model.predict(X_test)
        label_accuracies = []
        accuracies_dict = {}
        for i in range(y_test.shape[1]):
            accuracy = np.mean((predictions[:, i] > 0.5) == y_test[:, i])
            label_accuracies.append(accuracy)
            accuracies_dict[expected_data.columns[i]] = [f"{accuracy:.3f}"]

        # Listing the accuracy for each label in table form
        accuracies_df = pd.DataFrame(accuracies_dict, index=['Accuracy'])
        print(accuracies_df)

        # Average accuracy for all labels
        mean_label_accuracy = np.mean(label_accuracies)
        fold_labels_accuracies.append(label_accuracies)
        print(f'Mean accuracy for all 11 labels: {mean_label_accuracy:.4f}\n')

        fold_no += 1

    overall_accuracies.append(fold_accuracies)
    all_labels_accuracies.append(fold_labels_accuracies)
    print()
# Out:
# Repeat 1, Fold 1 started.
# Score for repeat 1, fold 1: compile_metrics of 0.1137
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.708  0.788        0.862    0.930  0.950   0.720   0.794  0.825
#
#          Positive Negative Neutral
# Accuracy    0.710    0.730   0.780
# Mean accuracy for all 11 labels: 0.7996
#
# Repeat 1, Fold 2 started.
# Score for repeat 1, fold 2: compile_metrics of 0.1165
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.715  0.791        0.858    0.925  0.950   0.708   0.822  0.830
#
#          Positive Negative Neutral
# Accuracy    0.724    0.710   0.781
# Mean accuracy for all 11 labels: 0.8013
#
# Repeat 1, Fold 3 started.
# Score for repeat 1, fold 3: compile_metrics of 0.1172
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.695  0.810        0.860    0.929  0.955   0.712   0.794  0.819
#
#          Positive Negative Neutral
# Accuracy    0.704    0.715   0.773
# Mean accuracy for all 11 labels: 0.7969
#
# Repeat 1, Fold 4 started.
# Score for repeat 1, fold 4: compile_metrics of 0.1053
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.713  0.803        0.854    0.914  0.945   0.706   0.822  0.840
#
#          Positive Negative Neutral
# Accuracy    0.727    0.715   0.805
# Mean accuracy for all 11 labels: 0.8041
#
# Repeat 1, Fold 5 started.
# Score for repeat 1, fold 5: compile_metrics of 0.1619
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.699  0.816        0.865    0.918  0.949   0.731   0.807  0.817
#
#          Positive Negative Neutral
# Accuracy    0.708    0.727   0.801
# Mean accuracy for all 11 labels: 0.8035
#
#
# Repeat 2, Fold 1 started.
# Score for repeat 2, fold 1: compile_metrics of 0.1151
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.688  0.762        0.863    0.916  0.939   0.713   0.787  0.819
#
#          Positive Negative Neutral
# Accuracy    0.697    0.725   0.789
# Mean accuracy for all 11 labels: 0.7905
#
# Repeat 2, Fold 2 started.
# Score for repeat 2, fold 2: compile_metrics of 0.1409
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.718  0.801        0.863    0.921  0.959   0.725   0.813  0.844
#
#          Positive Negative Neutral
# Accuracy    0.726    0.726   0.794
# Mean accuracy for all 11 labels: 0.8082
#
# Repeat 2, Fold 3 started.
# Score for repeat 2, fold 3: compile_metrics of 0.1039
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.707  0.806        0.841    0.920  0.957   0.711   0.801  0.815
#
#          Positive Negative Neutral
# Accuracy    0.708    0.713   0.761
# Mean accuracy for all 11 labels: 0.7944
#
# Repeat 2, Fold 4 started.
# Score for repeat 2, fold 4: compile_metrics of 0.1541
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.706  0.819        0.851    0.923  0.941   0.724   0.819  0.828
#
#          Positive Negative Neutral
# Accuracy    0.724    0.724   0.805
# Mean accuracy for all 11 labels: 0.8058
#
# Repeat 2, Fold 5 started.
# Score for repeat 2, fold 5: compile_metrics of 0.1424
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.701  0.796        0.871    0.905  0.952   0.716   0.815  0.798
#
#          Positive Negative Neutral
# Accuracy    0.719    0.708   0.796
# Mean accuracy for all 11 labels: 0.7980
#
#
# Repeat 3, Fold 1 started.
# Score for repeat 3, fold 1: compile_metrics of 0.1060
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.700  0.775        0.867    0.926  0.946   0.723   0.791  0.827
#
#          Positive Negative Neutral
# Accuracy    0.704    0.735   0.784
# Mean accuracy for all 11 labels: 0.7980
#
# Repeat 3, Fold 2 started.
# Score for repeat 3, fold 2: compile_metrics of 0.1192
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.709  0.805        0.870    0.925  0.955   0.729   0.834  0.830
#
#          Positive Negative Neutral
# Accuracy    0.708    0.727   0.774
# Mean accuracy for all 11 labels: 0.8059
#
# Repeat 3, Fold 3 started.
# Score for repeat 3, fold 3: compile_metrics of 0.1360
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.709  0.812        0.837    0.938  0.959   0.710   0.782  0.805
#
#          Positive Negative Neutral
# Accuracy    0.715    0.713   0.801
# Mean accuracy for all 11 labels: 0.7983
#
# Repeat 3, Fold 4 started.
# Score for repeat 3, fold 4: compile_metrics of 0.1102
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.695  0.803        0.841    0.923  0.946   0.736   0.825  0.848
#
#          Positive Negative Neutral
# Accuracy    0.702    0.738   0.776
# Mean accuracy for all 11 labels: 0.8030
#
# Repeat 3, Fold 5 started.
# Score for repeat 3, fold 5: compile_metrics of 0.1263
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.696  0.807        0.864    0.923  0.955   0.726   0.813  0.819
#
#          Positive Negative Neutral
# Accuracy    0.709    0.717   0.802
# Mean accuracy for all 11 labels: 0.8029
#
#
# Repeat 4, Fold 1 started.
# Score for repeat 4, fold 1: compile_metrics of 0.1234
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.698  0.776        0.859    0.927  0.945   0.707   0.802  0.832
#
#          Positive Negative Neutral
# Accuracy    0.707    0.711   0.778
# Mean accuracy for all 11 labels: 0.7949
#
# Repeat 4, Fold 2 started.
# Score for repeat 4, fold 2: compile_metrics of 0.1116
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.717  0.794        0.847    0.925  0.953   0.735   0.825  0.833
#
#          Positive Negative Neutral
# Accuracy    0.720    0.727   0.795
# Mean accuracy for all 11 labels: 0.8065
#
# Repeat 4, Fold 3 started.
# Score for repeat 4, fold 3: compile_metrics of 0.1367
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.702  0.815        0.864    0.931  0.946   0.704   0.794  0.808
#
#          Positive Negative Neutral
# Accuracy    0.720    0.705   0.774
# Mean accuracy for all 11 labels: 0.7967
#
# Repeat 4, Fold 4 started.
# Score for repeat 4, fold 4: compile_metrics of 0.0934
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.715  0.803        0.842    0.920  0.948   0.726   0.823  0.831
#
#          Positive Negative Neutral
# Accuracy    0.722    0.745   0.789
# Mean accuracy for all 11 labels: 0.8057
#
# Repeat 4, Fold 5 started.
# Score for repeat 4, fold 5: compile_metrics of 0.1431
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.703  0.811        0.857    0.922  0.949   0.729   0.813  0.824
#
#          Positive Negative Neutral
# Accuracy    0.707    0.724   0.786
# Mean accuracy for all 11 labels: 0.8022
#
#
# Repeat 5, Fold 1 started.
# Score for repeat 5, fold 1: compile_metrics of 0.1151
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.688  0.774        0.856    0.930  0.952   0.715   0.781  0.824
#
#          Positive Negative Neutral
# Accuracy    0.695    0.707   0.769
# Mean accuracy for all 11 labels: 0.7900
#
# Repeat 5, Fold 2 started.
# Score for repeat 5, fold 2: compile_metrics of 0.1457
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.718  0.810        0.868    0.923  0.962   0.715   0.818  0.847
#
#          Positive Negative Neutral
# Accuracy    0.725    0.717   0.783
# Mean accuracy for all 11 labels: 0.8079
#
# Repeat 5, Fold 3 started.
# Score for repeat 5, fold 3: compile_metrics of 0.1192
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.715  0.801        0.858    0.933  0.955   0.705   0.807  0.824
#
#          Positive Negative Neutral
# Accuracy    0.712    0.704   0.778
# Mean accuracy for all 11 labels: 0.7992
#
# Repeat 5, Fold 4 started.
# Score for repeat 5, fold 4: compile_metrics of 0.2078
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.687  0.804        0.858    0.921  0.946   0.734   0.828  0.845
#
#          Positive Negative Neutral
# Accuracy    0.697    0.734   0.781
# Mean accuracy for all 11 labels: 0.8033
#
# Repeat 5, Fold 5 started.
# Score for repeat 5, fold 5: compile_metrics of 0.1326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.708  0.809        0.853    0.911  0.946   0.723   0.810  0.825
#
#          Positive Negative Neutral
# Accuracy    0.710    0.716   0.789
# Mean accuracy for all 11 labels: 0.8001

# %% [markdown]
# # Final results

# %%
final_overall_accuracy = np.mean(overall_accuracies)
final_labels_accuracy = np.mean(all_labels_accuracies, axis=(0, 1))
overall_std = np.std(overall_accuracies)
labels_std = np.std(all_labels_accuracies, axis=(0, 1))

# %%
print(f'Final average overall accuracy: {final_overall_accuracy:.4f} with std deviation: {overall_std:.4f}')
print("\nFinal average accuracy for each label with their std deviation:")
for label, acc, std in zip(expected_data.columns, final_labels_accuracy, labels_std):
    print(f"{label}: {acc:.4f} (std: {std:.4f})")
# Out:
# Final average overall accuracy: 0.1279 with std deviation: 0.0233
#
# Final average accuracy for each label with their std deviation:
# Joy: 0.7043 (std: 0.0095)
# Trust: 0.7997 (std: 0.0143)
# Anticipation: 0.8571 (std: 0.0093)
# Surprise: 0.9232 (std: 0.0070)
# Fear: 0.9505 (std: 0.0057)
# Sadness: 0.7193 (std: 0.0099)
# Disgust: 0.8088 (std: 0.0148)
# Anger: 0.8263 (std: 0.0124)
# Positive: 0.7120 (std: 0.0095)
# Negative: 0.7206 (std: 0.0108)
# Neutral: 0.7858 (std: 0.0117)
