# %% [markdown]
# # Load Libraries

# %%
import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

import pickle
# Out:
# C:\Users\panko\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\scipy\__init__.py:177: UserWarning: A NumPy version >=1.18.5 and <1.26.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Mount the drive and change the directory

# %%
import os
os.chdir("../../../")
# from google.colab import drive
# drive.mount('/content/drive/')
# %cd drive/MyDrive/poleval_emotion/

# %% [markdown]
# # Determine constants

# %%
TRAIN_DIR = 'data/train/'
IN_FILENAME = 'in_gpt_corr.tsv'
EXPECTED_FILENAME = 'expected.tsv'

# %%
MODEL_DIR = 'models/'
TOKENIZERS_DIR = 'models/tokenizers/'
OUTPUT_MODEL_FILENAME = 'lstm_gpt_corr'

# %% [markdown]
# # Load & preprocess data functions

# %%
def load_data(file_path):
    data = pd.read_csv(file_path, sep='\t')
    return data

# %%
def preprocess_data(text_series, num_words=5000):
    tokenizer = Tokenizer(num_words=num_words)
    tokenizer.fit_on_texts(text_series)
    sequences = tokenizer.texts_to_sequences(text_series)
    max_len = max(len(x) for x in sequences)
    padded_sequences = pad_sequences(sequences, maxlen=max_len)
    return padded_sequences, tokenizer

# %% [markdown]
# # Define the LSTM model

# %%
def create_model(input_length):
    model = Sequential([
        Embedding(input_dim=5000, output_dim=128, input_length=input_length),
        LSTM(64),
        Dense(11, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %% [markdown]
# # Load & preprocess the data

# %%
in_data = load_data(TRAIN_DIR + IN_FILENAME)
expected_data = load_data(TRAIN_DIR + EXPECTED_FILENAME)

# %%
X, tokenizer = preprocess_data(in_data['text'])
y = expected_data.values

# %% [markdown]
# # Main operation

# %%
input_length = X.shape[1]
model = create_model(input_length)
# Out:
# C:\Users\panko\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.fit(X, y, batch_size=32, epochs=32)
# Out:
# Epoch 1/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 32s 128ms/step - accuracy: 0.0819 - loss: 0.5351
# Epoch 2/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 125ms/step - accuracy: 0.0411 - loss: 0.4090
# Epoch 3/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 30s 135ms/step - accuracy: 0.1023 - loss: 0.3409
# Epoch 4/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 29s 130ms/step - accuracy: 0.1342 - loss: 0.2935
# Epoch 5/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 31s 136ms/step - accuracy: 0.1501 - loss: 0.2630
# Epoch 6/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 27s 120ms/step - accuracy: 0.1610 - loss: 0.2303
# Epoch 7/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 125ms/step - accuracy: 0.1719 - loss: 0.2041
# Epoch 8/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 26s 115ms/step - accuracy: 0.1962 - loss: 0.1826
# Epoch 9/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 122ms/step - accuracy: 0.1840 - loss: 0.1741
# Epoch 10/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 31s 136ms/step - accuracy: 0.1900 - loss: 0.1560
# Epoch 11/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 27s 118ms/step - accuracy: 0.1698 - loss: 0.1418
# Epoch 12/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 126ms/step - accuracy: 0.1944 - loss: 0.1296
# Epoch 13/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 31s 137ms/step - accuracy: 0.1697 - loss: 0.1220
# Epoch 14/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 27s 121ms/step - accuracy: 0.1807 - loss: 0.1187
# Epoch 15/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 30s 132ms/step - accuracy: 0.2039 - loss: 0.1058
# Epoch 16/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 29s 127ms/step - accuracy: 0.1986 - loss: 0.1109
# Epoch 17/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 38s 169ms/step - accuracy: 0.1976 - loss: 0.0957
# Epoch 18/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 37s 162ms/step - accuracy: 0.1756 - loss: 0.0931
# Epoch 19/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 33s 146ms/step - accuracy: 0.1959 - loss: 0.0813
# Epoch 20/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 30s 133ms/step - accuracy: 0.1790 - loss: 0.0726
# Epoch 21/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 25s 112ms/step - accuracy: 0.1723 - loss: 0.0696
# Epoch 22/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 35s 153ms/step - accuracy: 0.2013 - loss: 0.0758
# Epoch 23/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 30s 134ms/step - accuracy: 0.2021 - loss: 0.0704
# Epoch 24/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 30s 133ms/step - accuracy: 0.1846 - loss: 0.0869
# Epoch 25/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 33s 147ms/step - accuracy: 0.2130 - loss: 0.1025
# Epoch 26/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 29s 128ms/step - accuracy: 0.2109 - loss: 0.0593
# Epoch 27/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.2016 - loss: 0.0569
# Epoch 28/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 27s 118ms/step - accuracy: 0.1957 - loss: 0.0507
# Epoch 29/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 26s 116ms/step - accuracy: 0.1883 - loss: 0.0483
# Epoch 30/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.1877 - loss: 0.0457
# Epoch 31/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 125ms/step - accuracy: 0.1839 - loss: 0.0454
# Epoch 32/32
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 26s 116ms/step - accuracy: 0.1813 - loss: 0.0440

# %% [markdown]
# # Save model

# %%
model.save(MODEL_DIR + OUTPUT_MODEL_FILENAME + '.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# # Tokenizer save

# %%
with open(TOKENIZERS_DIR + OUTPUT_MODEL_FILENAME + '.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
