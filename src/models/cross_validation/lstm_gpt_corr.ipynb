# %% [markdown]
# # Load Libraries

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split, KFold
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
# Out:
# C:\Users\panko\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\scipy\__init__.py:177: UserWarning: A NumPy version >=1.18.5 and <1.26.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Mount the drive and change the directory

# %%
import os
os.chdir("../../../")
# from google.colab import drive
# drive.mount('/content/drive/')
# %cd drive/MyDrive/poleval_emotion/

# %% [markdown]
# # Determine constants

# %%
TRAIN_DIR = 'data/train/'
IN_FILENAME = 'in_gpt_corr.tsv'
EXPECTED_FILENAME = 'expected.tsv'

# %% [markdown]
# # Load & preprocess data functions

# %%
def load_data(file_path):
    data = pd.read_csv(file_path, sep='\t')
    return data

# %%
def preprocess_data(text_series, num_words=5000):
    tokenizer = Tokenizer(num_words=num_words)
    tokenizer.fit_on_texts(text_series)
    sequences = tokenizer.texts_to_sequences(text_series)
    max_len = max(len(x) for x in sequences)
    padded_sequences = pad_sequences(sequences, maxlen=max_len)
    return padded_sequences, tokenizer

# %% [markdown]
# # Define the LSTM model

# %%
def create_model():
    model = Sequential([
        Embedding(input_dim=5000, output_dim=128),
        LSTM(64),
        Dense(11, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %% [markdown]
# # Load & preprocess the data

# %%
in_data = load_data(TRAIN_DIR + IN_FILENAME)
expected_data = load_data(TRAIN_DIR + EXPECTED_FILENAME)

# %%
X, tokenizer = preprocess_data(in_data['text'])
y = expected_data.values

# %% [markdown]
# # Cross-validation setup

# %%
num_splits = 5
num_repeats = 5
kf = KFold(n_splits=num_splits, shuffle=True, random_state=1613)

# %% [markdown]
# # Main operation

# %%
overall_accuracies = []
all_labels_accuracies = []

# %%
for repeat in range(num_repeats):
    fold_accuracies = []
    fold_labels_accuracies = []
    fold_no = 1
    for train_index, test_index in kf.split(X):
        print(f"Repeat {repeat+1}, Fold {fold_no} started.")
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]

        model = create_model()
        history = model.fit(X_train, y_train, batch_size=32, epochs=16, validation_data=(X_test, y_test), verbose=0)

        # Model evaluation
        scores = model.evaluate(X_test, y_test, verbose=0)
        fold_accuracies.append(scores[1])
        print(f'Score for repeat {repeat+1}, fold {fold_no}: {model.metrics_names[1]} of {scores[1]:.4f}')

        # Calculating the accuracy for each label
        predictions = model.predict(X_test)
        label_accuracies = []
        accuracies_dict = {}
        for i in range(y_test.shape[1]):
            accuracy = np.mean((predictions[:, i] > 0.5) == y_test[:, i])
            label_accuracies.append(accuracy)
            accuracies_dict[expected_data.columns[i]] = [f"{accuracy:.3f}"]

        # Listing the accuracy for each label in table form
        accuracies_df = pd.DataFrame(accuracies_dict, index=['Accuracy'])
        print(accuracies_df)

        # Average accuracy for all labels
        mean_label_accuracy = np.mean(label_accuracies)
        fold_labels_accuracies.append(label_accuracies)
        print(f'Mean accuracy for all 11 labels: {mean_label_accuracy:.4f}\n')

        fold_no += 1

    overall_accuracies.append(fold_accuracies)
    all_labels_accuracies.append(fold_labels_accuracies)
    print()
# Out:
# Repeat 1, Fold 1 started.
# Score for repeat 1, fold 1: compile_metrics of 0.1297
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.696  0.768        0.862    0.913  0.956   0.737   0.806  0.809
#
#          Positive Negative Neutral
# Accuracy    0.706    0.733   0.760
# Mean accuracy for all 11 labels: 0.7951
#
# Repeat 1, Fold 2 started.
# Score for repeat 1, fold 2: compile_metrics of 0.1311
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.697  0.792        0.847    0.911  0.957   0.728   0.816  0.825
#
#          Positive Negative Neutral
# Accuracy    0.693    0.726   0.785
# Mean accuracy for all 11 labels: 0.7979
#
# Repeat 1, Fold 3 started.
# Score for repeat 1, fold 3: compile_metrics of 0.1290
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.730  0.791        0.854    0.933  0.956   0.720   0.789  0.817
#
#          Positive Negative Neutral
# Accuracy    0.717    0.727   0.774
# Mean accuracy for all 11 labels: 0.8006
#
# Repeat 1, Fold 4 started.
# Score for repeat 1, fold 4: compile_metrics of 0.1395
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.707  0.796        0.850    0.923  0.952   0.715   0.809  0.844
#
#          Positive Negative Neutral
# Accuracy    0.709    0.720   0.782
# Mean accuracy for all 11 labels: 0.8007
#
# Repeat 1, Fold 5 started.
# Score for repeat 1, fold 5: compile_metrics of 0.1326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.703  0.785        0.849    0.913  0.950   0.727   0.786  0.807
#
#          Positive Negative Neutral
# Accuracy    0.702    0.720   0.779
# Mean accuracy for all 11 labels: 0.7930
#
#
# Repeat 2, Fold 1 started.
# Score for repeat 2, fold 1: compile_metrics of 0.1374
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.701  0.780        0.859    0.931  0.955   0.745   0.811  0.822
#
#          Positive Negative Neutral
# Accuracy    0.709    0.736   0.763
# Mean accuracy for all 11 labels: 0.8010
#
# Repeat 2, Fold 2 started.
# Score for repeat 2, fold 2: compile_metrics of 0.1618
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.700  0.789        0.858    0.923  0.952   0.705   0.818  0.817
#
#          Positive Negative Neutral
# Accuracy    0.698    0.709   0.786
# Mean accuracy for all 11 labels: 0.7958
#
# Repeat 2, Fold 3 started.
# Score for repeat 2, fold 3: compile_metrics of 0.1269
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.713  0.798        0.865    0.934  0.957   0.719   0.787  0.803
#
#          Positive Negative Neutral
# Accuracy    0.718    0.732   0.779
# Mean accuracy for all 11 labels: 0.8005
#
# Repeat 2, Fold 4 started.
# Score for repeat 2, fold 4: compile_metrics of 0.1074
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.715  0.794        0.853    0.921  0.948   0.722   0.807  0.827
#
#          Positive Negative Neutral
# Accuracy    0.722    0.724   0.785
# Mean accuracy for all 11 labels: 0.8015
#
# Repeat 2, Fold 5 started.
# Score for repeat 2, fold 5: compile_metrics of 0.1158
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.699  0.798        0.865    0.910  0.950   0.727   0.773  0.804
#
#          Positive Negative Neutral
# Accuracy    0.696    0.712   0.786
# Mean accuracy for all 11 labels: 0.7927
#
#
# Repeat 3, Fold 1 started.
# Score for repeat 3, fold 1: compile_metrics of 0.1199
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.691  0.768        0.851    0.926  0.957   0.728   0.801  0.822
#
#          Positive Negative Neutral
# Accuracy    0.692    0.722   0.770
# Mean accuracy for all 11 labels: 0.7935
#
# Repeat 3, Fold 2 started.
# Score for repeat 3, fold 2: compile_metrics of 0.1311
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.702  0.779        0.862    0.914  0.955   0.704   0.821  0.847
#
#          Positive Negative Neutral
# Accuracy    0.691    0.717   0.794
# Mean accuracy for all 11 labels: 0.7986
#
# Repeat 3, Fold 3 started.
# Score for repeat 3, fold 3: compile_metrics of 0.1450
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.715  0.803        0.864    0.934  0.950   0.739   0.803  0.800
#
#          Positive Negative Neutral
# Accuracy    0.706    0.739   0.780
# Mean accuracy for all 11 labels: 0.8030
#
# Repeat 3, Fold 4 started.
# Score for repeat 3, fold 4: compile_metrics of 0.1318
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.702  0.796        0.842    0.919  0.951   0.724   0.803  0.833
#
#          Positive Negative Neutral
# Accuracy    0.707    0.736   0.798
# Mean accuracy for all 11 labels: 0.8011
#
# Repeat 3, Fold 5 started.
# Score for repeat 3, fold 5: compile_metrics of 0.1410
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.692  0.795        0.868    0.913  0.951   0.720   0.795  0.808
#
#          Positive Negative Neutral
# Accuracy    0.701    0.719   0.772
# Mean accuracy for all 11 labels: 0.7941
#
#
# Repeat 4, Fold 1 started.
# Score for repeat 4, fold 1: compile_metrics of 0.1534
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.695  0.772        0.870    0.930  0.953   0.717   0.794  0.808
#
#          Positive Negative Neutral
# Accuracy    0.695    0.716   0.771
# Mean accuracy for all 11 labels: 0.7928
#
# Repeat 4, Fold 2 started.
# Score for repeat 4, fold 2: compile_metrics of 0.1185
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.699  0.781        0.858    0.925  0.950   0.729   0.810  0.841
#
#          Positive Negative Neutral
# Accuracy    0.694    0.731   0.780
# Mean accuracy for all 11 labels: 0.7998
#
# Repeat 4, Fold 3 started.
# Score for repeat 4, fold 3: compile_metrics of 0.1611
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.707  0.785        0.864    0.911  0.945   0.732   0.775  0.803
#
#          Positive Negative Neutral
# Accuracy    0.707    0.732   0.775
# Mean accuracy for all 11 labels: 0.7941
#
# Repeat 4, Fold 4 started.
# Score for repeat 4, fold 4: compile_metrics of 0.1283
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.713  0.797        0.858    0.925  0.951   0.715   0.784  0.842
#
#          Positive Negative Neutral
# Accuracy    0.725    0.722   0.796
# Mean accuracy for all 11 labels: 0.8026
#
# Repeat 4, Fold 5 started.
# Score for repeat 4, fold 5: compile_metrics of 0.1528
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.690  0.782        0.860    0.923  0.952   0.722   0.793  0.814
#
#          Positive Negative Neutral
# Accuracy    0.692    0.708   0.779
# Mean accuracy for all 11 labels: 0.7923
#
#
# Repeat 5, Fold 1 started.
# Score for repeat 5, fold 1: compile_metrics of 0.1430
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.685  0.775        0.865    0.920  0.953   0.734   0.804  0.813
#
#          Positive Negative Neutral
# Accuracy    0.691    0.731   0.758
# Mean accuracy for all 11 labels: 0.7935
#
# Repeat 5, Fold 2 started.
# Score for repeat 5, fold 2: compile_metrics of 0.1367
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.695  0.786        0.862    0.921  0.961   0.713   0.796  0.835
#
#          Positive Negative Neutral
# Accuracy    0.695    0.709   0.797
# Mean accuracy for all 11 labels: 0.7974
#
# Repeat 5, Fold 3 started.
# Score for repeat 5, fold 3: compile_metrics of 0.1778
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.711  0.786        0.876    0.934  0.946   0.722   0.776  0.815
#
#          Positive Negative Neutral
# Accuracy    0.702    0.725   0.787
# Mean accuracy for all 11 labels: 0.7981
#
# Repeat 5, Fold 4 started.
# Score for repeat 5, fold 4: compile_metrics of 0.1304
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 126ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.702  0.787        0.848    0.928  0.947   0.713   0.786  0.852
#
#          Positive Negative Neutral
# Accuracy    0.713    0.718   0.788
# Mean accuracy for all 11 labels: 0.7983
#
# Repeat 5, Fold 5 started.
# Score for repeat 5, fold 5: compile_metrics of 0.1221
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step
#             Joy  Trust Anticipation Surprise   Fear Sadness Disgust  Anger  \
# Accuracy  0.701  0.793        0.865    0.921  0.950   0.726   0.794  0.815
#
#          Positive Negative Neutral
# Accuracy    0.706    0.729   0.790
# Mean accuracy for all 11 labels: 0.7990

# %% [markdown]
# # Final results

# %%
final_overall_accuracy = np.mean(overall_accuracies)
final_labels_accuracy = np.mean(all_labels_accuracies, axis=(0, 1))
overall_std = np.std(overall_accuracies)
labels_std = np.std(all_labels_accuracies, axis=(0, 1))

# %%
print(f'Final average overall accuracy: {final_overall_accuracy:.4f} with std deviation: {overall_std:.4f}')
print("\nFinal average accuracy for each label with their std deviation:")
for label, acc, std in zip(expected_data.columns, final_labels_accuracy, labels_std):
    print(f"{label}: {acc:.4f} (std: {std:.4f})")
# Out:
# Final average overall accuracy: 0.1362 with std deviation: 0.0156
#
# Final average accuracy for each label with their std deviation:
# Joy: 0.7026 (std: 0.0097)
# Trust: 0.7869 (std: 0.0095)
# Anticipation: 0.8589 (std: 0.0080)
# Surprise: 0.9222 (std: 0.0077)
# Fear: 0.9522 (std: 0.0038)
# Sadness: 0.7233 (std: 0.0097)
# Disgust: 0.7975 (std: 0.0132)
# Anger: 0.8209 (std: 0.0151)
# Positive: 0.7035 (std: 0.0097)
# Negative: 0.7237 (std: 0.0087)
# Neutral: 0.7806 (std: 0.0108)
